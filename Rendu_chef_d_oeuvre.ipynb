# %%
import pygame
import random
import os

pygame.init()

WINDOW_WIDTH, WINDOW_HEIGHT = 800, 600
screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
pygame.display.set_caption("Jeu de l'aligot")

BLACK = (0, 0, 0)
WHITE = (255, 255, 255)


img_path = "img"
aligot_img = pygame.image.load(os.path.join(img_path, "aligot.png"))
fraise_img = pygame.image.load(os.path.join(img_path, "fraise.png"))
pomme_img = pygame.image.load(os.path.join(img_path, "pomme.png"))
mangue_img = pygame.image.load(os.path.join(img_path, "mangue.png"))
citron_img = pygame.image.load(os.path.join(img_path, "citron.png"))

# Redimensionnement des images
aligot_img = pygame.transform.scale(aligot_img, (50, 50))
fraise_img = pygame.transform.scale(fraise_img, (40, 40))
pomme_img = pygame.transform.scale(pomme_img, (40, 40))
mangue_img = pygame.transform.scale(mangue_img, (40, 40))
citron_img = pygame.transform.scale(citron_img, (40, 40))

# Police et variables
font = pygame.font.Font(None, 36)
score = 0
time_limit = 60  # Durée en secondes
clock = pygame.time.Clock()
start_ticks = None 


text_color = BLACK  


fruits = [
    {"image": fraise_img, "score": 2, "color": (255, 0, 0)},
    {"image": pomme_img, "score": 4, "color": (0, 255, 0)},
    {"image": mangue_img, "score": 6, "color": (255, 165, 0)},
    {"image": citron_img, "score": 10, "color": (255, 255, 0)},
]

# Générer des positions aléatoires pour les fruits
def generate_fruit():
    fruit = random.choice(fruits)
    x = random.randint(50, WINDOW_WIDTH - 50)
    y = random.randint(50, WINDOW_HEIGHT - 50)
    return {"fruit": fruit, "pos": (x, y)}

# Initialisation des fruits
fruit_objects = [generate_fruit() for _ in range(5)]

# Position initiale de l'aligot
aligot_pos = [WINDOW_WIDTH // 2, WINDOW_HEIGHT // 2]
aligot_speed = 5

# Fonction pour afficher le score
def draw_score():
    score_text = font.render(f"Score: {score}", True, text_color)
    screen.blit(score_text, (WINDOW_WIDTH - 150, 10))

# Fonction pour afficher le timer
def draw_timer():
    if start_ticks is not None:
        elapsed_time = (pygame.time.get_ticks() - start_ticks) // 1000
        remaining_time = max(0, time_limit - elapsed_time)
        timer_text = font.render(f"Time: {remaining_time}s", True, text_color)
        screen.blit(timer_text, (10, 10))
        return remaining_time
    else:
        timer_text = font.render(f"Time: {time_limit}s", True, text_color)
        screen.blit(timer_text, (10, 10))
        return time_limit

# Boucle principale
running = True
background_color = WHITE

while running:
    screen.fill(background_color)


    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False


    keys = pygame.key.get_pressed()
    moved = False
    if keys[pygame.K_UP]:
        aligot_pos[1] -= aligot_speed
        moved = True
    if keys[pygame.K_DOWN]:
        aligot_pos[1] += aligot_speed
        moved = True
    if keys[pygame.K_LEFT]:
        aligot_pos[0] -= aligot_speed
        moved = True
    if keys[pygame.K_RIGHT]:
        aligot_pos[0] += aligot_speed
        moved = True


    if moved and start_ticks is None:
        start_ticks = pygame.time.get_ticks()
        text_color = BLACK  

    aligot_pos[0] = max(0, min(WINDOW_WIDTH - 50, aligot_pos[0]))
    aligot_pos[1] = max(0, min(WINDOW_HEIGHT - 50, aligot_pos[1]))

    screen.blit(aligot_img, aligot_pos)

    for obj in fruit_objects:
        screen.blit(obj["fruit"]["image"], obj["pos"])

    # Collision avec les fruits
    aligot_rect = pygame.Rect(aligot_pos[0], aligot_pos[1], 50, 50)
    for obj in fruit_objects:
        fruit_rect = pygame.Rect(obj["pos"][0], obj["pos"][1], 40, 40)
        if aligot_rect.colliderect(fruit_rect):
            score += obj["fruit"]["score"]
            background_color = obj["fruit"]["color"]
            fruit_objects.remove(obj)
            fruit_objects.append(generate_fruit())

    draw_score()
    remaining_time = draw_timer()

    # Fin du jeu après le temps imparti
    if remaining_time <= 0:
        running = False

    pygame.display.flip()
    clock.tick(30)

# Affichage du score final
screen.fill(BLACK)
final_score_text = font.render(f"Score final : {score}", True, WHITE)
screen.blit(final_score_text, (WINDOW_WIDTH // 2 - 100, WINDOW_HEIGHT // 2))
pygame.display.flip()
pygame.time.wait(3000)

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Ce chef d'oeuvre a été codé en python, étant donnée que l'on a utilisé ce langage tout le long du cours, j'ai préféré rester sur le même langage de programmation afin de m'entrainer dessus et d'avoir un autre projet à ajouter à mon portfolio.
#
# L'idée de ce projet m'est venue lorsque j'ai discuté avec mes camarades de classe. Le thème a été choisi car une personne que je connais aime l'aligot et les fruits qui apparaissent à l'écran.
#
# Mon idée, à la base, était d'utiliser Flask pour pouvoir l'héberger sur Heroku, donc d'avoir un back en python et un front en html, css et js. Mais je me suis rendu compte qu'utiliser Pygame et un canevas allait être plus compliqué que prévu. Il aurait fallait que j'envoie des screenshots en BMP à chaque seconde pour mettre à jour l'affichage sur le site web : cela aurait pris plus de temps.
#
# J'ai donc juste fais comme vu en cours, un code python simple qui affiche une fenêtre avec un jeu. Le but du jeu est simple : capturer des fruits, ils ont un score différent, et il faut, en 60 secondes, avoir le plus grand score possible (je crois que j'ai réussi à obtenir 400 dans le train). J'ai déssiné moi-même les fruits (et l'aligot qui est le personnage principal) sur mon ipad, comme ça aucun problème de droits d'auteurs ou je ne sais quoi. Comme dis précedemment j'ai utilisé la bibliothèque Pygame qui permet de créer des jeux en python, j'ai aussi utilisé la biblitothèque random car j'avais besoin de générer des positions aléatoires pour les fruits. La bibliothèques OS sert à ce que les chemins de fichiers soient chargés peu importe le système d'exploitation sur lequel on exécute le code, les chemins contiennent des '/' sous linux/macOS tandis que sous windows c'est des '\'. Elle permet une meilleure portabilité du code (ce qui pourrait servir sachant que vous détestez Windows, il est donc très probable que vous exécutiez ce code sous Linux).
#
# On va maintenant lister 10 techniques propres au multimédia et à l'animation présentes dans le code:
# -   L'affiche des images, les Sprites, donc les fruits et l'aligot que l'on voit à l'écran lorsqu'on lance le programme python, ce sont des éléments graphiques essentiels pour afficher visuellement les objets ou personnages dans le jeu. (multimédia) on utilise des spritesheets
# -   Animation par déplacement qui va être le déplacement de l'aligot dans notre cas, mais sinon c'est le déplacement des objets et personnages (Animation du coup, c'est le premier mot en plus). Les touches du clavier permettent de modifier les coordonnées de l'objet grâce à un déplacement. C'est de l'interpolation linéaire (lerp)
# -   La détection des collisions qui repose sur des calculs (en gros si l'aligot et un objet ont les mêmes coordonnées il y a collision), nos objets sont représentés par des rectangles, on vérifie juste si ils se touchent ou non. (multimédia) c'est du bounding box collision detection dans notre cas et il y a aussi du collision layering.
# -   La synchronisation des évènements (comme par exemple le timer qui se lance au moment où l'on bouge notre personnage) fait partie de l'animation qui permet de structurer les actions du jeu. Ou alors juste le timer qui fonctionne. (Animation) c'est de l'event-driven programming et du timeline-based animation
# -   La redimension des images afin de les adapter à notre jeu. (multimedia) c'est à priori du mipmapping et du scaling algorithms pour ne pas avoir de perte significative de qualité
# -   Le jeu est produit en redessinant l'écran à chaque cycle, c'est du frame-by-frame rendering (grâce à une game loop). (multimédia)
# -   Le changement de couleur de fond dynamique qui se produit lorsque l'on va sur un fruit. (multimédia) utilisation de shaders pour manipuler dynamiquement les couleurs et des color gradients
# -   La génération aléatoire des fruits influence le visuel sans animation particulière. (multimédia) il y a du random number génération : du pseduo-aléatoire pour déterminer la position des fruits. il y a aussi du procedural generation pour générer du contenu varié en temps réel dans le jeu
# -   L'affichage du score et du timer font partie de la conception graphique du jeu. (multimedia) layering, bitmaps fonts et UI design
# -   Les entrées de l'utilisateur via les touches du clavier déclenchent un mouvement animé, c'est de l'animation interactive. (animation) event polling pour que chaque entrée utilisateur soit prise en compte de l'input handling et de l'animation blending
#
# Mon oeuvre admet un seul type d'entrée : les flèches directionnelles du clavier.
# Il n'y a pas de tableau des scores, ni de BDD pour sauvegarder votre partie, ni un compteur qui permet de savoir combien de fois vous avez mangé/capturé X fruit; votre fruit le plus capturé, combien de temps vous mettez en moyenne pour aller capturer Y fruits. Ce sont certains exemples des limites de mon oeuvre.
# je pourrais tenter d'ajouter un mode multijoueur.
